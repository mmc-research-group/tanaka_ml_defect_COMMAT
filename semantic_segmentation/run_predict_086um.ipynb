# %%
run predict_086um.py -i cut_ufg2_img_000.png -o output_0001.png
# Out:
# 0
# st 926
# 5
# st 884
# 10
# st 912
# 15
# st 936
# 20
# st 945
# 25
# st 888
# 30
# st 857
# 35
# st 927
# 40
# st 951
# 45
# st 984
# 50
# st 1156
# 55
# st 1264
# 60
# st 1317
# 65
# st 1246
# 70
# st 1141
# 75
# st 944
# 80
# st 754
# 85
# st 1760
# 90
# st 2024
# 95
# st 1610
# 100
# st 1915
# 105
# st 1769
# 110
# st 2071
# 115
# st 3712
# 120
# st 4151
# 125
# st 4199
# 130
# st 4240
# 135
# st 4310
# 140
# st 4434
# 145
# st 4015
# 150
# st 4135
# 155
# st 4515
# 160
# st 4846
# 165
# st 5694
# 170
# st 4749
# 175
# st 5290
# 180
# st 5374
# 185
# st 5630
# 190
# st 10225
# 195
# st 10604
# 200
# st 11103
# 205
# st 11209
# 210
# st 11545
# 215
# st 11678
# 220
# st 11531
# 225
# st 11795
# 230
# st 11931
# 235
# st 12358
# 240
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/COMMAT/semantic_segmentation/predict_086um.py:117
# ...
