# %%
run predict_086um.py -i cut_ufg2_img_000.png -o output_0001.png
# Out:
# 0
# (2, 400, 398)
# [[     0    926]
#  [     1 158274]]
# st 926
# 5
# (2, 400, 398)
# [[     0    884]
#  [     1 158316]]
# st 884
# 10
# (2, 400, 398)
# [[     0    912]
#  [     1 158288]]
# st 912
# 15
# (2, 400, 398)
# [[     0    936]
#  [     1 158264]]
# st 936
# 20
# (2, 400, 398)
# [[     0    945]
#  [     1 158255]]
# st 945
# 25
# (2, 400, 398)
# [[     0    888]
#  [     1 158312]]
# st 888
# 30
# (2, 400, 398)
# [[     0    857]
#  [     1 158343]]
# st 857
# 35
# (2, 400, 398)
# [[     0    927]
#  [     1 158273]]
# st 927
# 40
# (2, 400, 398)
# [[     0    951]
#  [     1 158249]]
# st 951
# 45
# (2, 400, 398)
# [[     0    984]
#  [     1 158216]]
# st 984
# 50
# (2, 400, 398)
# [[     0   1156]
#  [     1 158044]]
# st 1156
# 55
# (2, 400, 398)
# [[     0   1264]
#  [     1 157936]]
# st 1264
# 60
# (2, 400, 398)
# [[     0   1317]
#  [     1 157883]]
# st 1317
# 65
# (2, 400, 398)
# [[     0   1246]
#  [     1 157954]]
# st 1246
# 70
# (2, 400, 398)
# ...
